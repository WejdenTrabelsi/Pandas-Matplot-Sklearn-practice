# %% [markdown]
# <h1 style ="font-family: verdana; text-size:14pt; text-align:center;color:blue;">TP1: La Visualisation des Données </h1>

# %% [markdown]
# <h3 style ="font-family: verdana; text-size:12pt; text-decoration:underline;">Exercice 1 </h3>

# %%
#création des listes années et population 
annee =[1960,1970,1980,1990,2000,2010,2011,2012,2013,2014,2019,2022]
population =[4220701,5127000,6384000,8154400,9563500,10547000,10673800,10776400,10886500,10982754,11658341,11803588]

# %%
annee
type(annee)
# Out:
# list

# %%
import matplotlib.pyplot as plt 
plt.plot(annee,population)
plt.show()
